# %% [markdown]
# ## Import

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Functional Plot

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1 ** 2
plt.plot(x_1, y_1)
plt.title('Days Squared Chart')
plt.xlabel('Days')
plt.ylabel('Days Squared')
plt.show()

# %% [markdown]
# ## Print Multiple Plots

# %%
plt.subplot(1,2,1)
plt.plot(x_1,y_1,'r--')
plt.subplot(1,2,2)
plt.plot(x_1, y_1, 'b-')
plt.show()

# %% [markdown]
# ## Using Figure Objects
#
# A figure is an Object that contains all the plot elements and it can contain many axis

# %%
fig_1 = plt.figure(figsize=(5,4), dpi=100)
axes_1 = fig_1.add_axes([0, 0, 1, 1])
axes_1.set_xlabel('Days')
axes_1.set_ylabel('Days Squared')
axes_1.set_title('Days Squared Chart')
axes_1.plot(x_1, y_1, label='x/x2')
axes_1.plot(y_1, x_1, label='x2/x')
# upper right: 1, upper left: 2, lower left: 3, lower right: 4,
# or supply a tuple of x & y from lower left
axes_1.legend(loc=0)

axes_2 = fig_1.add_axes([0.5, 0.33, 0.4, 0.3])
axes_2.set_xlabel('Days')
axes_2.set_ylabel('Days Squared')
axes_2.set_title('Days Squared Chart')
axes_2.plot(x_1, y_1, label='x/x2')
axes_2.plot(y_1, x_1, label='x2/x')
axes_2.text(0, 35, 'Message')
# Out:
# Text(0, 35, 'Message')

# %% [markdown]
# ## SubPlots

# %%
fig_2, axes_2 = plt.subplots(figsize=(8,4), nrows=2, ncols=4, dpi=160)
plt.tight_layout()
axes_2[1][0].set_title('Plot 2')
axes_2[1][0].set_xlabel('X')
axes_2[1][0].set_ylabel('X Squared')
axes_2[1][0].plot(x_1,y_1)
axes_2[0][1].set_xlabel('Days')
axes_2[0][1].set_ylabel('Days Squared')
axes_2[0][1].set_title('Days Squared Chart')
axes_2[0][1].plot(x_1, y_1, label='x/x2')
axes_2[0][1].plot(y_1, x_1, label='x2/x')
axes_2[0][1].grid(True, color='0.6', dashes=(5, 2, 1, 2))
axes_2[0][1].set_facecolor('#faebd7')
plt.show()

# %% [markdown]
# ## Histograms

# %%
arr_1 = np.random.randint(1, 7, 6000)
arr_2 = np.random.randint(1, 7, 6000)
arr_3 = arr_1 + arr_2

plt.hist(arr_3, bins=11, density=True, stacked=True)
plt.show()

# %%
from matplotlib.animation import FuncAnimation
from itertools import count
import random
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
x_vals = []
y_vals = []

index = count()

def animate(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(0,5))
    plt.cla()
    plt.plot(x_vals, y_vals)
    
    
ani = FuncAnimation(plt.gcf() , animate, interval=1000)
    
plt.tight_layout()
plt.show()
